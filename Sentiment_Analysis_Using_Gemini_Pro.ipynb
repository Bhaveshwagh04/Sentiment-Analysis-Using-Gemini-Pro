# %% [markdown]
# ## Working Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/amazon_alexa.tsv
# Out:
# [Errno 20] Not a directory: '/content/drive/MyDrive/amazon_alexa.tsv'
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# ## Import Dataset

# %%
import pandas as pd

data = pd.read_csv('/amazon_alexa.tsv', sep='\t')
data.head(10)
# Out:
#    rating       date             variation  \
# 0       5  31-Jul-18      Charcoal Fabric
# 1       5  31-Jul-18      Charcoal Fabric
# 2       4  31-Jul-18        Walnut Finish
# 3       5  31-Jul-18      Charcoal Fabric
# 4       5  31-Jul-18      Charcoal Fabric
# 5       5  31-Jul-18  Heather Gray Fabric
# 6       3  31-Jul-18     Sandstone Fabric
# 7       5  31-Jul-18      Charcoal Fabric
# 8       5  30-Jul-18  Heather Gray Fabric
# 9       5  30-Jul-18  Heather Gray Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1
# 5  I received the echo as a gift. I needed anothe...         1
# 6  Without having a cellphone, I cannot use many ...         1
# 7  I think this is the 5th one I've purchased. I'...         1
# 8                                        looks great         1
# 9  Love it! I’ve listened to songs I haven’t hear...         1

# %%
mydata = data[['verified_reviews','feedback']]
mydata.columns = ['review','label']

mydata.head()
# Out:
#                                               review  label
# 0                                      Love my Echo!      1
# 1                                          Loved it!      1
# 2  Sometimes while playing a game, you can answer...      1
# 3  I have had a lot of fun with this thing. My 4 ...      1
# 4                                              Music      1

# %%
mydata.value_counts('label')
# Out:
# label
# 1    2893
# 0     257
# Name: count, dtype: int64

# %%
# Count the occurrences of each label
label_counts = mydata["label"].value_counts()

# Get the number of rows to drop from the majority class
rows_to_drop = label_counts.max() - label_counts.min()

# Drop rows from the majority class randomly
if rows_to_drop > 0:
   data_majority = mydata[mydata["label"] == 1]
   data_balanced = mydata.drop(data_majority.sample(rows_to_drop).index)
else:
   data_balanced = mydata.copy()

# Check the new class balance
print(data_balanced["label"].value_counts())
# Out:
# label
# 1    257
# 0    257
# Name: count, dtype: int64

# %% [markdown]
# ## Data Perprocessing

# %%
import re

def clean_text(text):
  # Remove special characters and punctuation
  text = re.sub(r"[^\w\s]", " ", text)

  # Remove single characters
  text = re.sub(r"\b[a-zA-Z]\b", " ", text)

  # Remove HTML tags
  text = re.sub(r"<[^>]*>", " ", text)

  # Lowercase the text
  text = text.lower()

  # Remove extra whitespace
  text = re.sub(r"\s+", " ", text)

  # Trim leading and trailing spaces
  text = text.strip()

  return text

# %%
import pandas as pd
import re

# Extract the review column as a list
reviews = data_balanced['review'].tolist()

# Clean the text in the list, handling non-string elements
cleaned_reviews = []
for review in reviews:
    if isinstance(review, str):  # Check if the review is a string
        cleaned_reviews.append(clean_text(review))
    else:
        cleaned_reviews.append('')  # Or handle it as needed

# Add the cleaned reviews as a new column to the DataFrame
data_balanced['clean_reviews'] = cleaned_reviews

# %%
data_balanced
# Out:
#                                                  review  label  \
# 4                                                 Music      1
# 19    I liked the original Echo. This is the same bu...      1
# 26    I love my Echo. It's easy to operate, loads of...      1
# 39    This is my first digital assistant so I'm givi...      1
# 46    It's like Siri, in fact, Siri answers more acc...      0
# ...                                                 ...    ...
# 3096  The product sounded the same as the emoji spea...      0
# 3102  Works great, love the fact you can play the sa...      1
# 3116            I enjoy it. Still discovering new uses.      1
# 3121  I like the hands free operation vs the Tap. We...      1
# 3136  I used it to control my smart home devices. Wo...      1
#
#                                           clean_reviews
# 4                                                 music
# 19    liked the original echo this is the same but s...
# 26    love my echo it easy to operate loads of fun i...
# 39    this is my first digital assistant so giving t...
# 46    it like siri in fact siri answers more accurat...
# ...                                                 ...
# 3096  the product sounded the same as the emoji spea...
# 3102  works great love the fact you can play the sam...
# 3116                enjoy it still discovering new uses
# 3121  like the hands free operation vs the tap we us...
# 3136  used it to control my smart home devices works...
#
# [514 rows x 3 columns]

# %% [markdown]
# # Data Split

# %%
import pandas as pd

# Assuming your DataFrame is called "df"
total_rows = len(data_balanced)
test_size = int(total_rows * 0.95)

# Randomly sample train_size rows for the training set
test_set = data_balanced.sample(test_size)

# Get the remaining rows for the test set
train_set = data_balanced.drop(test_set.index)

# %% [markdown]
# ## Sentiment w/ LLM

# %% [markdown]
# ## Setting up Gemini API

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.3/718.3 kB 7.1 MB/s eta 0:00:00

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Used to securely store your API key
from google.colab import userdata

# %%
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-1.5-pro')

# %%
# %%time
response = model.generate_content("What is the meaning of life?")

to_markdown(response.text)
# Out:
# CPU times: user 194 ms, sys: 20.7 ms, total: 214 ms
# Wall time: 11.4 s
# > As a large language model, I can't tell you the meaning of life. That's a question philosophers have pondered for millennia and there's no one right answer.  It's a question each person must answer for themselves.
# >
# > However, I can offer some ideas to help you explore this question:
# >
# > * **Purpose and meaning are not the same:** Some find meaning in having a purpose, like a career goal or a family to build.  Others find meaning in the journey itself, finding joy in everyday experiences and connections.
# > * **It's about what matters to you:** What do you value? What brings you joy, fulfillment, and a sense of peace?  Exploring these questions can reveal what gives your life meaning.
# > * **Meaning can change and evolve:** What gives your life meaning today might not be the same thing tomorrow, and that's okay.  Life is a journey of growth and discovery.
# > * **It's okay not to have all the answers:**  Some find meaning in the search itself.  Embrace the mystery and keep asking questions.
# >
# > Here are some resources you might find helpful in your exploration:
# >
# > * **Philosophical texts:**  Read about different perspectives on the meaning of life. Start with philosophers like Socrates, Plato, Aristotle, or explore different schools of thought like existentialism, stoicism, or absurdism.
# > * **Spiritual or religious texts:** If you're drawn to spirituality, explore religious texts or teachings that resonate with you.
# > * **Self-reflection:** Spend time in nature, meditate, journal, or talk to a trusted friend or therapist. Reflect on your values, experiences, and aspirations.
# >
# > Ultimately, the meaning of life is what you make it. It's a journey of self-discovery, connection, and finding what makes your heart sing.

# %% [markdown]
# ## Single API Call

# %%
test_set_sample = test_set.sample(20)

test_set_sample['pred_label'] = ''

test_set_sample
# Out:
#                                                  review  label  \
# 1233  I purchased this on prime day mostly as a pres...      1
# 2197                                                         0
# 499   Now I'm weary about these picking up conversat...      0
# 382                         Poor quality. Gave it away.      0
# 2664                      HANDY AS HELL 10/10 RECOMMEND      1
# 900   It's got great sound and bass but it doesn't w...      0
# 566   The second one which was a refurbished model d...      0
# 668   It's ok. The speaker is pretty terrible. Googl...      0
# 2095  As an echo its great, Good sound quality and f...      0
# 1716  Need to be able to connect to more 3rd party v...      0
# 1689  Works fine, I just realize I don’t need this b...      0
# 542   Purchased for my 83 year old mother-she loves ...      1
# 173   BEST father's day gift. Dad joked to my mom th...      1
# 160   Works great! Killer speaker! My wife and son l...      1
# 1044  Great device.  Seems to work better than the 1...      1
# 440   Have had an larger echo for some time and love...      1
# 2090  I am the Training Coordinator at my company an...      1
# 1951  The echo part works fine.  The hue hub is a di...      0
# 2772                                                         1
# 480   You could not tell this was refurbished. Works...      1
#
#                                           clean_reviews pred_label
# 1233  purchased this on prime day mostly as present ...
# 2197
# 499   now weary about these picking up conversations...
# 382                           poor quality gave it away
# 2664                      handy as hell 10 10 recommend
# 900   it got great sound and bass but it doesn work ...
# 566   the second one which was refurbished model did...
# 668   it ok the speaker is pretty terrible google ho...
# 2095  as an echo its great good sound quality and fu...
# 1716  need to be able to connect to more 3rd party v...
# 1689  works fine just realize don need this because ...
# 542   purchased for my 83 year old mother she loves ...
# 173   best father day gift dad joked to my mom that ...
# 160   works great killer speaker my wife and son lov...
# 1044  great device seems to work better than the 1st...
# 440   have had an larger echo for some time and love...
# 2090  am the training coordinator at my company and ...
# 1951  the echo part works fine the hue hub is disast...
# 2772
# 480   you could not tell this was refurbished works ...

# %%
# Convert the DataFrame to JSON using the to_json() method

json_data = test_set_sample[['clean_reviews','pred_label']].to_json(orient='records')

# Print the JSON data
print(json_data)
# Out:
# [{"clean_reviews":"purchased this on prime day mostly as present for myself because found having the echo plus on my kitchen counter to be overwhelming when cooking cutting cleaning etc especially when our counters aren very wide to begin with after going back and forth between this and the show decided on this because felt it had all the same features but is more compact can honestly say have no regrets while probably wouldn watch movie been dying to see on this it great way to listen to music watch quick youtube video etc even attempted watching jaws on this and while it wasn the most comfortable thing for my eyes to do it wasn as bad as one would think would definitely recommend","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"now weary about these picking up conversations when you are not actively using them heard about this happening on the news have 3 4 so this is very concerning wish amazon would release something widespread or push some firmware to prevent this if they have have not heard about it yet","pred_label":""},{"clean_reviews":"poor quality gave it away","pred_label":""},{"clean_reviews":"handy as hell 10 10 recommend","pred_label":""},{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":""},{"clean_reviews":"the second one which was refurbished model did work at least not in my home","pred_label":""},{"clean_reviews":"it ok the speaker is pretty terrible google home is better product","pred_label":""},{"clean_reviews":"as an echo its great good sound quality and functionality as smart home hub it sucks no automation no geo fencing no music syncing for hue no wave all it does is turn things on with your voice ended up buying smartthing hub and transferring everything over","pred_label":""},{"clean_reviews":"need to be able to connect to more 3rd party viceo apps","pred_label":""},{"clean_reviews":"works fine just realize don need this because don use it","pred_label":""},{"clean_reviews":"purchased for my 83 year old mother she loves talking to alexa very responsive can detect its name from all over the room","pred_label":""},{"clean_reviews":"best father day gift dad joked to my mom that alexa will be the one listening to all of his repeated stories going forward","pred_label":""},{"clean_reviews":"works great killer speaker my wife and son love it","pred_label":""},{"clean_reviews":"great device seems to work better than the 1st generation","pred_label":""},{"clean_reviews":"have had an larger echo for some time and love it bought this one for another portion of the house since we have several wifi home devices and we wanted to voice control them from all over the house","pred_label":""},{"clean_reviews":"am the training coordinator at my company and have used the amazon blueprints skill with an echo device and echo buttons to create my own gameshow quiz for new hire orientation training always looking for new ways to engage trainees in order to make learning more enjoyable believe that if someone enjoys the process of learning then they re much more likely to remember the information so far this has been huge success with my classes and look forward to amazon improving and building out the blueprints skill further","pred_label":""},{"clean_reviews":"the echo part works fine the hue hub is disaster it worked for few months and then nothing spent 2 hours on the phone with tech support one to have to send it in for repair am now trying to reconnect my lights what pain am having to reset each light bulb it can take up to 5 times to get it to reset have spent hours on this will say customer service was friendly and tried to be helpful stick with the echo and smart plugs for lamps","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"you could not tell this was refurbished works excellent would highly recommended instead of purchasing new","pred_label":""}]

# %%
prompt = f"""
You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
Customer reviews are provided between three back ticks.
In your output, only return the Json code back as output - which is provided between three backticks.
Your task is to update predicted labels under 'pred_label' in the Json code.
Don't make any changes to Json code format, please.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
# Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
# Customer reviews are provided between three back ticks.
# In your output, only return the Json code back as output - which is provided between three backticks.
# Your task is to update predicted labels under 'pred_label' in the Json code.
# Don't make any changes to Json code format, please.
#
# ```
# [{"clean_reviews":"purchased this on prime day mostly as present for myself because found having the echo plus on my kitchen counter to be overwhelming when cooking cutting cleaning etc especially when our counters aren very wide to begin with after going back and forth between this and the show decided on this because felt it had all the same features but is more compact can honestly say have no regrets while probably wouldn watch movie been dying to see on this it great way to listen to music watch quick youtube video etc even attempted watching jaws on this and while it wasn the most comfortable thing for my eyes to do it wasn as bad as one would think would definitely recommend","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"now weary about these picking up conversations when you are not actively using them heard about this happening on the news have 3 4 so this is very concerning wish amazon would release something widespread or push some firmware to prevent this if they have have not heard about it yet","pred_label":""},{"clean_reviews":"poor quality gave it away","pred_label":""},{"clean_reviews":"handy as hell 10 10 recommend","pred_label":""},{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":""},{"clean_reviews":"the second one which was refurbished model did work at least not in my home","pred_label":""},{"clean_reviews":"it ok the speaker is pretty terrible google home is better product","pred_label":""},{"clean_reviews":"as an echo its great good sound quality and functionality as smart home hub it sucks no automation no geo fencing no music syncing for hue no wave all it does is turn things on with your voice ended up buying smartthing hub and transferring everything over","pred_label":""},{"clean_reviews":"need to be able to connect to more 3rd party viceo apps","pred_label":""},{"clean_reviews":"works fine just realize don need this because don use it","pred_label":""},{"clean_reviews":"purchased for my 83 year old mother she loves talking to alexa very responsive can detect its name from all over the room","pred_label":""},{"clean_reviews":"best father day gift dad joked to my mom that alexa will be the one listening to all of his repeated stories going forward","pred_label":""},{"clean_reviews":"works great killer speaker my wife and son love it","pred_label":""},{"clean_reviews":"great device seems to work better than the 1st generation","pred_label":""},{"clean_reviews":"have had an larger echo for some time and love it bought this one for another portion of the house since we have several wifi home devices and we wanted to voice control them from all over the house","pred_label":""},{"clean_reviews":"am the training coordinator at my company and have used the amazon blueprints skill with an echo device and echo buttons to create my own gameshow quiz for new hire orientation training always looking for new ways to engage trainees in order to make learning more enjoyable believe that if someone enjoys the process of learning then they re much more likely to remember the information so far this has been huge success with my classes and look forward to amazon improving and building out the blueprints skill further","pred_label":""},{"clean_reviews":"the echo part works fine the hue hub is disaster it worked for few months and then nothing spent 2 hours on the phone with tech support one to have to send it in for repair am now trying to reconnect my lights what pain am having to reset each light bulb it can take up to 5 times to get it to reset have spent hours on this will say customer service was friendly and tried to be helpful stick with the echo and smart plugs for lamps","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"you could not tell this was refurbished works excellent would highly recommended instead of purchasing new","pred_label":""}]
# ```

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ```
# [{"clean_reviews":"purchased this on prime day mostly as present for myself because found having the echo plus on my kitchen counter to be overwhelming when cooking cutting cleaning etc especially when our counters aren very wide to begin with after going back and forth between this and the show decided on this because felt it had all the same features but is more compact can honestly say have no regrets while probably wouldn watch movie been dying to listen to music watch quick youtube video etc even attempted watching jaws on this and while it wasn the most comfortable thing for my eyes to do it wasn as bad as one would think would definitely recommend","pred_label":1},{"clean_reviews":"","pred_label":""},{"clean_reviews":"now weary about these picking up conversations when you are not actively using them heard about this happening on the news have 3 4 so this is very concerning wish amazon would release something widespread or push some firmware to prevent this if they have have not heard about it yet","pred_label":0},{"clean_reviews":"poor quality gave it away","pred_label":0},{"clean_reviews":"handy as hell 10 10 recommend","pred_label":1},{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":0},{"clean_reviews":"the second one which was refurbished model did work at least not in my home","pred_label":0},{"clean_reviews":"it ok the speaker is pretty terrible google home is better product","pred_label":0},{"clean_reviews":"as an echo its great good sound quality and functionality as smart home hub it sucks no automation no geo fencing no music syncing for hue no wave all it does is turn things on with your voice ended up buying smartthing hub and transferring everything over","pred_label":0},{"clean_reviews":"need to be able to connect to more 3rd party viceo apps","pred_label":0},{"clean_reviews":"works fine just realize don need this because don use it","pred_label":0},{"clean_reviews":"purchased for my 83 year old mother she loves talking to alexa very responsive can detect its name from all over the room","pred_label":1},{"clean_reviews":"best father day gift dad joked to my mom that alexa will be the one listening to all of his repeated stories going forward","pred_label":1},{"clean_reviews":"works great killer speaker my wife and son love it","pred_label":1},{"clean_reviews":"great device seems to work better than the 1st generation","pred_label":1},{"clean_reviews":"have had an larger echo for some time and love it bought this one for another portion of the house since we have several wifi home devices and we wanted to voice control them from all over the house","pred_label":1},{"clean_reviews":"am the training coordinator at my company and have used the amazon blueprints skill with an echo device and echo buttons to create my own gameshow quiz for new hire orientation training always looking for new ways to engage trainees in order to make learning more enjoyable believe that if someone enjoys the process of learning then they re much more likely to remember the information so far this has been huge success with my classes and look forward to amazon improving and building out the blueprints skill further","pred_label":1},{"clean_reviews":"the echo part works fine the hue hub is disaster it worked for few months and then nothing spent 2 hours on the phone with tech support one to have to send it in for repair am now trying to reconnect my lights what pain am having to reset each light bulb it can take up to 5 times to get it to reset have spent hours on this will say customer service was friendly and tried to be helpful stick with the echo and smart plugs for lamps","pred_label":0},{"clean_reviews":"","pred_label":""},{"clean_reviews":"you could not tell this was refurbished works excellent would highly recommended instead of purchasing new","pred_label":1}]
# ```

# %%
import json

# Clean the data by stripping potential extra characters
json_data = response.text.strip("`\n")  # Strip newlines as well

# Check if the response starts and ends with square brackets (indicating a JSON array)
if json_data.startswith('[') and json_data.endswith(']'):
    # Load the cleaned data and convert to DataFrame
    data = json.loads(json_data)
    df_sample = pd.DataFrame(data)
else:
    print("Unexpected response format. The model might not be returning a valid JSON array.")
    print(json_data)  # Print the raw response for inspection

df_sample
# Out:
#                                         clean_reviews pred_label
# 0   purchased this on prime day mostly as present ...          1
# 1
# 2   now weary about these picking up conversations...          0
# 3                           poor quality gave it away          0
# 4                       handy as hell 10 10 recommend          1
# 5   it got great sound and bass but it doesn work ...          0
# 6   the second one which was refurbished model did...          0
# 7   it ok the speaker is pretty terrible google ho...          0
# 8   as an echo its great good sound quality and fu...          0
# 9   need to be able to connect to more 3rd party v...          0
# 10  works fine just realize don need this because ...          0
# 11  purchased for my 83 year old mother she loves ...          1
# 12  best father day gift dad joked to my mom that ...          1
# 13  works great killer speaker my wife and son lov...          1
# 14  great device seems to work better than the 1st...          1
# 15  have had an larger echo for some time and love...          1
# 16  am the training coordinator at my company and ...          1
# 17  the echo part works fine the hue hub is disast...          0
# 18
# 19  you could not tell this was refurbished works ...          1

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_sample['pred_label'] = df_sample['pred_label'].values
test_set_sample
# Out:
#                                                  review  label  \
# 1233  I purchased this on prime day mostly as a pres...      1
# 2197                                                         0
# 499   Now I'm weary about these picking up conversat...      0
# 382                         Poor quality. Gave it away.      0
# 2664                      HANDY AS HELL 10/10 RECOMMEND      1
# 900   It's got great sound and bass but it doesn't w...      0
# 566   The second one which was a refurbished model d...      0
# 668   It's ok. The speaker is pretty terrible. Googl...      0
# 2095  As an echo its great, Good sound quality and f...      0
# 1716  Need to be able to connect to more 3rd party v...      0
# 1689  Works fine, I just realize I don’t need this b...      0
# 542   Purchased for my 83 year old mother-she loves ...      1
# 173   BEST father's day gift. Dad joked to my mom th...      1
# 160   Works great! Killer speaker! My wife and son l...      1
# 1044  Great device.  Seems to work better than the 1...      1
# 440   Have had an larger echo for some time and love...      1
# 2090  I am the Training Coordinator at my company an...      1
# 1951  The echo part works fine.  The hue hub is a di...      0
# 2772                                                         1
# 480   You could not tell this was refurbished. Works...      1
#
#                                           clean_reviews pred_label
# 1233  purchased this on prime day mostly as present ...          1
# 2197
# 499   now weary about these picking up conversations...          0
# 382                           poor quality gave it away          0
# 2664                      handy as hell 10 10 recommend          1
# 900   it got great sound and bass but it doesn work ...          0
# 566   the second one which was refurbished model did...          0
# 668   it ok the speaker is pretty terrible google ho...          0
# 2095  as an echo its great good sound quality and fu...          0
# 1716  need to be able to connect to more 3rd party v...          0
# 1689  works fine just realize don need this because ...          0
# 542   purchased for my 83 year old mother she loves ...          1
# 173   best father day gift dad joked to my mom that ...          1
# 160   works great killer speaker my wife and son lov...          1
# 1044  great device seems to work better than the 1st...          1
# 440   have had an larger echo for some time and love...          1
# 2090  am the training coordinator at my company and ...          1
# 1951  the echo part works fine the hue hub is disast...          0
# 2772
# 480   you could not tell this was refurbished works ...          1

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np

y_true = test_set_sample["label"]
y_pred = test_set_sample["pred_label"]

# Convert y_pred to numeric, handling non-numeric values
y_pred_numeric = pd.to_numeric(y_pred, errors='coerce').fillna(-1).astype(int)

# Filter out rows with missing predictions (-1)
valid_indices = y_pred_numeric != -1
y_true_valid = y_true[valid_indices]
y_pred_valid = y_pred_numeric[valid_indices]

confusion_matrix(y_true_valid, y_pred_valid)
# Out:
# array([[9, 0],
#        [0, 9]])
